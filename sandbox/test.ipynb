# %%
import sklearn

# %%
sklearn.__file__
# Out:
# '/home/shun/.local/lib/python3.10/site-packages/sklearn/__init__.py'

# %%
import pandas as pd
from sklearn.datasets import fetch_california_housing
from sklearn.linear_model import Ridge

data = fetch_california_housing()
X = pd.DataFrame(data.data, columns=data.feature_names)
y = pd.Series(data.target, name='Price')

model = Ridge()
model.fit(X, y)

pd.DataFrame(model.coef_, index=X.columns, columns=['coef'])
# Out:
# /Users/cubicbox/.venv/lib/python3.10/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/cubicbox/.venv/lib/python3.10/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/cubicbox/.venv/lib/python3.10/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
#                 coef
# MedInc      0.436594
# HouseAge    0.009437
# AveRooms   -0.107133
# AveBedrms   0.644062
# Population -0.000004
# AveOccup   -0.003786
# Latitude   -0.421299
# Longitude  -0.434485
